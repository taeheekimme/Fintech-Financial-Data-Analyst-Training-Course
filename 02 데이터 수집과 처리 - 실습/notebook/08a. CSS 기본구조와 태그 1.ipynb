# %%
<!DOCTYPE HTML> # html 시작

<html lang=“en”> #언어설정: english



<head> #헤드 시작

<meta content="text/html; charset=utf-8" />

<title>CSS 셀렉터 예문 </title> #브라우저 탭 이름

</head> #헤드 끝



<style> #스타일 시작

h1 { #h1태그에 적용

color:blue; #글자색

background-color:gray; #글자 배경색

font-weight:bolder; #글자굵기

}

h2 { #h2태그에 적용

color:red;

background-color:yellow;

font-weight:lighter;

}

p { #p태그에 적용

color:green;

background-color:orange;

font-weight:normal;

}

div { # div태그에 적용

color:white;

background-color:red;

font-weight:normal;

}

ol { #ol태그에 적용

color:white;

background-color:darkgreen;

font-weight:normal;

}

</style> #스타일 끝



<body> #바디 시작

<h1> 헤더 1.1 </h1>

<h1> 헤더 1.2 </h1>


<p> Paragraph 1. </p>

<p> Paragraph 2. </p>



<div>

<br>

<span> A Single line within a div tag. </span>

<br>

<p> Paragraph 4. </p>

<p> Paragraph 5. </p>

<br>

</div>


<br>

<div>

<br>

다음은 ordered list이다:

<ol>

<li> 아이템 하나. </li>

<li> 아이템 둘. </li>


</ol>

<br>

</div>



</body> #바디 끝



</html> #html 끝

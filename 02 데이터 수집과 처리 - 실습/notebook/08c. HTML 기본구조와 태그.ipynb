# %% [markdown]
# <head>
# <meta content = "text/html; charset = utf-8"/ >
# <title>Title</title>
# </head>
#
#
#
# <body>
#
# <h1> 제일 큰 폰트 </h1>
#
# <h2> 두 번째로 큰 폰트</h2>
#
# <h3> 세 번째로 큰 폰트</h3>
#
#
# <p> 문단 내용 </p>
#
#
# <p> <span style = "color:Red;">문단 내용</span> </p>
#
#
# <div>
#
# 다음은 unordered list 이다:
#
# <ul>
#
# <li> 아이템 하나. </li>
#
# <li> 아이템 둘. </li>
#
# <li> 아이템 셋. </li>
#
# </ul>
#
# </div>
#
#
# <div>
#
# 다음은 ordered list이다:
#
# <ol>
#
# <li> 아이템 하나. </li>
#
# <li> 아이템 둘. </li>
#
# <li> 아이템 셋. </li>
#
# </ol>
#
# </div>
#
#
# <div>
#
# 다음은 ordered list인데 색상을 넣어 본다:
#
# <ol>
#
# <li> <span style="color:Red;">아이템 하나.</span> </li>
#
# <li> <span style="color:Blue;">아이템 둘. </span> </li>
#
# <li> <span style="color:Green;">아이템 셋. </span> </li>
#
# </ol>
#
# </div>
#
#
# <p>
#
# <a href = "http://www.naver.com"> 네이버</a> <br> <br>
#
# <a href = ".\page_01a.html"> 로컬 파일</a> <br> <br>
#
# <em> 기울임 폰트</em> <br> <br>
#
# <strong> 볼드체 </strong> <br> <br>
#
# <b> 볼드체 </b><br> <br>
#
# <i> 이탤릭체</i> <br> <br>
#
# <u>밑줄</u>
#
# </p>
#
#
# <div>
#
# <input type="text" value="test1">
#
# <input type="text" value="test2">
#
# <input type="text" value="test3">
#
#
# <button>Button 1</button>
#
# <button>Button 2</button>
#
# <button>Button 3</button>
#
#
# <select>
#
# <option value="선택_1">선택_1</option>
#
# <option value="선택_2">선택_2</option>
#
# <option value="선택_3">선택_3</option>
#
# <option value="선택_4">선택_4</option>
#
# </select>
#
# </div>
#
#
#
# </body>
#
#
# </html>

# %%
<!DOCTYPE html> #html 시작

<html lang = "en"> #언어설정 english



<head> #헤드 시작

<meta content = "text/html; charset = utf-8"/ > #문서에 대한 설명

<title>Title</title> #브라우저 탭 이름

</head> #헤드 끝



<body> #바디 시작

<h1> 제일 큰 폰트 </h1>

<h2> 두 번째로 큰 폰트</h2>

<h3> 세 번째로 큰 폰트</h3>

<p> 문단 내용 </p>

<p> <span style = "color:Red;">문단 내용</span> </p> #span태그로 글자색 바꾸기


<div> #내부적으로 구조를 나누고플 때

다음은 unordered list 이다: #번호없는 정렬

<ul>

<li> 아이템 하나. </li> #리스트 아이템 추가

<li> 아이템 둘. </li>

<li> 아이템 셋. </li>

</ul>

</div>


<div>

다음은 ordered list이다: #번호있는 정렬

<ol>

<li> 아이템 하나. </li>

<li> 아이템 둘. </li>

<li> 아이템 셋. </li>

</ol>

</div>


<div>

다음은 ordered list인데 색상을 넣어 본다:

<ol>

<li> <span style="color:Red;">아이템 하나.</span> </li>

<li> <span style="color:Blue;">아이템 둘. </span> </li>

<li> <span style="color:Green;">아이템 셋. </span> </li>

</ol>

</div>


<p>

<a href = "http://www.naver.com"> 네이버</a> <br> <br> #네이버로 가는 하이퍼링크

<a href = ".\page_01a.html"> 로컬 파일</a> <br> <br> #로컬파일로 가는 하이퍼링크

<em> 기울임 폰트</em> <br> <br>

<strong> 볼드체 </strong> <br> <br>

<b> 볼드체 </b><br> <br>

<i> 이탤릭체</i> <br> <br>

<u>밑줄</u>

</p>


<div>

<input type="text" value="test1"> #데이터를 넣는 폼 삽입

<input type="text" value="test2">

<input type="text" value="test3">


<button>Button 1</button> #버튼 삽입

<button>Button 2</button>

<button>Button 3</button>


<select> #드롭다운 선택 메뉴(화살표누르면 내용 나오는 것)

<option value="선택_1">선택_1</option>

<option value="선택_2">선택_2</option>

<option value="선택_3">선택_3</option>

<option value="선택_4">선택_4</option>

</select>

</div>



</body> #바디 끝



</html> #html 끝

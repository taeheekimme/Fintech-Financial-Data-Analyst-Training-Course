# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore') 
# %matplotlib inline
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# ## 1. 강남구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('강남구.xlsx') 
#df = pd.read_csv('동작구.csv', header='infer',encoding = 'ms949', na_values=[' '])
a_df.tail(5)
# Out:
#      Unnamed: 0               카페             메뉴    가격   지역 구분
# 282         219       이디야커피 삼성동점        아이스카푸치노  2200  강남구  F
# 283         288          에이쓰리커피집  아메리카노 (테이크아웃)  1800  강남구  P
# 284         253           제이스킹커피          아메리카노  1500  강남구  P
# 285          18         커피코트 강남점           드립커피  1000  강남구  F
# 286         200  커피코트 선릉 한신인터밸리점           드립커피  1000  강남구  F

# %%
#구별 카페종류별 카운트플롯
sns.countplot(x='지역', data=a_df, hue='구분')

# %%
#구별 카페종류별 바이올린플롯
#plt.savefig('fig1.png', dpi=300) #저장
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])
#plt.savefig('강남구바이올린.png', dpi=300) #저장
plt.show()

# %% [markdown]
# ## 2. 강동구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('강동구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 3. 강북구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('강북구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 4. 강서구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('강서구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 5. 관악구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('관악구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 6. 광진구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('광진구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 7. 구로구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('구로구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 8. 금천구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('금천구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 9. 노원구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('노원구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 10. 도봉구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('도봉구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 11. 동대문구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('동대문구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 12. 동작구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('동작구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 13. 마포구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('마포구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 14. 서대문구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('서대문구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 15. 서초구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('서초구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 16. 성동구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('성동구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 17. 성북구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('성북구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 18. 송파구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('송파구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 19. 양천구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('양천구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 20. 영등포구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('영등포구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 21. 용산구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('용산구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 22. 은평구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('은평구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 23. 종로구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('종로구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 24. 중구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('중구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])

# %% [markdown]
# ## 25. 중랑구

# %%
os.chdir(r"C:\Users\Gram\Desktop\myPyCode\크롤링을 활용한 구별 카페가격 비교\구별 엑셀파일(결측치 처리후)")
a_df = pd.read_excel('중랑구.xlsx') 
#구별 카페 바이올린플롯
plt.show()
fig = plt.subplots(figsize=(5,5))
sns.violinplot(x='구분', y='가격', data=a_df, palette='coolwarm',order=['F','P'])
